# %%
# %cd ..
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/dongmin/userdata/open-score-string-quartets
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import os
import sys
import subprocess
import warnings
from typing import Union, Any, Optional
import shutil
from pathlib import Path
from collections import Counter, defaultdict
from operator import itemgetter
from tempfile import NamedTemporaryFile, TemporaryDirectory

import math
import random

import json
import csv
import strictyaml as syaml

from tqdm import tqdm
import matplotlib.pyplot as plt

import cv2
import numpy as np
import partitura as pt

dformat = lambda d: json.dumps(d, indent=2)
dprint = lambda d: print(dformat(d))

# %%
PathLike = Union[Path, str]

# %%
root_dir = Path(os.getcwd())
data_dir = root_dir / 'data'
score_dir = root_dir / 'scores'

# %%
data_dir, score_dir
# Out:
# (PosixPath('/home/dongmin/userdata/open-score-string-quartets/data'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores'))

# %% [markdown]
# ## Load metadata

# %%
with open(data_dir / 'scores.yaml') as f:
  score_metadata = syaml.load(f.read())

score_metadata = score_metadata.data

mscore_data = [ dict( mscore_id=mscore_id, **obj ) for mscore_id, obj in score_metadata.items() ]

# %% [markdown]
# ## Copy MusicXML and Rendered Image from MuseScore 3.6.2
# all .mscx files were edited using **MuseScore3 v3.6.2**

# %%
for mscore_id, infos in score_metadata.items():
  ossq_id = f'sq{mscore_id}'
  
  mscore_dir = score_dir / infos['path'] 
  musicxml_path = mscore_dir / f"{ossq_id}.musicxml"
  image_paths = list(sorted((mscore_dir / 'images' / 'original').glob('*.png')))
  
  assert musicxml_path.exists(), f"old score: {str(musicxml_path)} does not exist"
  assert all([ p.exists() for p in image_paths ]), f"old score: some images do not exist"
  
  # delete old files
  musicxml_path.unlink()
  for p in image_paths:
    p.unlink()

print("old files deleted")

converted_dir = root_dir / 'local'

score_pbar = tqdm(score_metadata.items())
for mscore_id, infos in score_pbar:
  ossq_id = f'sq{mscore_id}'
  
  score_pbar.set_description(f"{ossq_id}")
  
  new_musicxml_path = converted_dir / ossq_id / f'{ossq_id}.musicxml'
  new_image_paths = list(sorted((converted_dir / ossq_id / 'images').glob('*.png')))
  
  assert new_musicxml_path.exists(), f"{str(new_musicxml_path)} does not exist"
  assert all([ p.exists() for p in new_image_paths ]), f"some images do not exist"
  
  mscore_dir = score_dir / infos['path'] 
  musicxml_path = mscore_dir / f"{ossq_id}.musicxml"
  image_dir = mscore_dir / 'images' / 'original'
  
  # copy new files
  shutil.copy(new_musicxml_path, musicxml_path)
  for src_img in new_image_paths:
    shutil.copy(src_img, image_dir / src_img.name)
# Out:
# old files deleted
# sq8823783: 100%|██████████| 122/122 [00:01<00:00, 74.90it/s]

# %% [markdown]
# ### delete old lmxe

# %%
score_pbar = tqdm(score_metadata.items())
for mscore_id, infos in score_pbar:
  ossq_id = f'sq{mscore_id}'
  score_pbar.set_description(f"{ossq_id}")
  
  mscore_dir = score_dir / infos['path'] 
  lmxe_paths = (mscore_dir / 'lmxe').glob('*.lmxe')
  lmxe_paths = list(sorted(lmxe_paths))
  
  for p in lmxe_paths:
    p.unlink()
# Out:
# sq8823783: 100%|██████████| 122/122 [00:00<00:00, 697.70it/s]

# %% [markdown]
# ## convert MuseScore files to MusicXML

# %%
for d in tqdm(mscore_data):
  mscore_dir = score_dir / d['path'] 
  mscore_path = mscore_dir / f"sq{d['mscore_id']}.mscx"
  
  out_path = mscore_dir / f"sq{d['mscore_id']}.musicxml"
  
  cmd = ['musescore3', "-o", out_path, mscore_path, '-f']
    
  try:
    # convert MuseScore file to MusicXML
    ps = subprocess.run(
      cmd, 
      stdout=subprocess.DEVNULL, stderr=subprocess.PIPE
    )
    
    if ps.returncode != 0:
      raise Exception(
        "Command {} failed with code {}. MuseScore " "error messages:\n {}"
        .format(cmd, ps.returncode, ps.stderr.decode("UTF-8"))
      )
  
  except Exception as e:
    raise Exception(
      'Executing "{}" returned  {}.'.format(" ".join(cmd), e)
    )

# %% [markdown]
# ## Headless MuseScore Load + Render

# %%
def pt_load_mscx(
  filename:PathLike,
  mscore_exec:str='musescore3',
  validate:bool=False,
  force_note_ids:Union[bool,str]='keep',
):
  """
  modified function from partitura.io.musescore.load_via_musescore
  """
  if isinstance(filename, Path):
    filename = str(filename)
  
  with NamedTemporaryFile(suffix=".musicxml") as xml_fh:
    cmd = [mscore_exec, "-o", xml_fh.name, filename, "-f"]
    
    try:
      # convert MuseScore file to MusicXML
      ps = subprocess.run(
        cmd, 
        stdout=subprocess.DEVNULL, stderr=subprocess.PIPE
      )
      
      if ps.returncode != 0:
        raise Exception(
          "Command {} failed with code {}. MuseScore " "error messages:\n {}"
          .format(cmd, ps.returncode, ps.stderr.decode("UTF-8"))
        )
    
    except Exception as e:
      raise Exception(
        'Executing "{}" returned  {}.'.format(" ".join(cmd), e)
      )

    score = pt.load_musicxml(
      filename=xml_fh.name,
      validate=validate,
      force_note_ids=force_note_ids,
    )
  
  return score

# %%
def pt_render_musescore(
  score_data: pt.score.ScoreLike,
  fmt:str='png',
  out:Union[PathLike,None]=None,
  dpi:Optional[int]=90,
  mscore_exec:str='musescore3'
) -> Union[list[PathLike],list[np.array],None]:
  """
  modified function from partitura.io.musescore.render_musescore
  Render a score-like object using musescore.

  Parameters
  ----------
  score_data : ScoreLike
    Score-like object to be rendered
  fmt : {'png', 'pdf'}
    Output image format
  out : Path or str or None
    'png': OPTIONAL
    'pdf': REQUIRED
  dpi : int, optional
    Image resolution. 
    This option is ignored when `fmt` is 'pdf'. 
    Defaults to 90.

  Returns
  -------
  out : 
    1. list[PathLike]: list of paths to output images if out is provided
    2. list[np.array]: list of images if out is not provided
    3. None: if no image was generated
  """
  
  assert fmt in {'png', 'pdf'}, "Unsupported output format"
  
  if fmt == 'pdf':
    assert out is not None, "Output path is required for 'pdf' format"

  with TemporaryDirectory() as tmpdir:
    xml_fh = Path(tmpdir) / "score.musicxml"
    img_fh = Path(tmpdir) / f"score.{fmt}"

    pt.save_musicxml(score_data, xml_fh)

    cmd = [
      mscore_exec,
      # "-T",
      # "10",
      "-r",
      "{}".format(int(dpi)),
      "-o",
      os.fspath(img_fh),
      os.fspath(xml_fh),
      "-f",
    ]
    try:
      ps = subprocess.run(
        cmd, 
        stdout=subprocess.PIPE, stderr=subprocess.PIPE,
      )
      
      if ps.returncode != 0:
        raise Exception(
          "Command {} failed with code {}; stdout: {}; stderr: {}"
          .format(
            cmd,
            ps.returncode,
            ps.stdout.decode("UTF-8"),
            ps.stderr.decode("UTF-8"),
          )
        )
    
    except Exception as e:
      raise Exception(
        'Executing "{}" returned  {}.'
        .format(" ".join(cmd), e),
      )
    
    if fmt == "png":
      # gether all generated image files
      img_files = list(sorted(Path(tmpdir).glob(f"*.{fmt}")))
      
      # if no image was generated
      if len(img_files) < 1:
        return None
      
      # return images if out is not provided
      if out is None:
        out_images = [ cv2.imread(i_fp) for i_fp in img_files ]
        return out_images

      # return paths of images if out is provided
      else:
        out_files = [ out/i_fp.name for i_fp in img_files ]
        for i_fp, o_fp in zip(img_files, out_files):
          # make background white
          o_i = cv2.imread(i_fp, cv2.IMREAD_UNCHANGED)
          transparent_mask = o_i[:,:,3] == 0
          o_i[transparent_mask] = [255, 255, 255, 255]
          o_i = cv2.cvtColor(o_i, cv2.COLOR_BGRA2BGR)
          cv2.imwrite(o_fp, o_i)
        return out_files
    
    elif fmt == "pdf":
      if img_fh.is_file():
        shutil.copy(img_fh, out/img_fh.name)
      else:
        return None
    
    # if no image was generated
    return None

# %%
data = mscore_data[0]
mscore_dir = score_dir / data['path'] 
mscore_path = mscore_dir / f"sq{data['mscore_id']}.mscx"
musicxml_path = mscore_dir / f"sq{data['mscore_id']}.musicxml"

# %%
musicxml_path
# Out:
# PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/sq7313978.musicxml')

# %%
score = pt.load_musicxml(musicxml_path)
# Out:
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1014: UserWarning: Dashes end without dashes start
#   warnings.warn("Dashes end without dashes start")
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:927: UserWarning: Did not find a wedge start element for wedge stop!
#   warnings.warn("Did not find a wedge start element for wedge stop!")
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "sul G" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "tranquillo" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "con sordino" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "Allegretto [Dubbelt da fort]" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "allarg." (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "3" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "rd" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing " corde" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-y': '3.83', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-y': '0.95', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-y': '15.55', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-y': '29.96', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-y': '21.24', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-y': '21.09', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-y': '32.97', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-x': '-34.94', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:429: UserWarning: Found repeat without start
# Starting point 0 is assumed
#   warnings.warn(
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "più svart " (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "pizz." (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "arco" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))

# %%
mscore_out_dir = mscore_dir / 'images' / 'original'
mscore_out_dir.mkdir(parents=True, exist_ok=True)

pt_render_musescore(
  score,
  fmt='png',
  out=mscore_out_dir,
  dpi=300,
)
# Out:
# [PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-01.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-02.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-03.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-04.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-05.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-06.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-07.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-08.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-09.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-10.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-11.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-12.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-13.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-14.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-15.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-16.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-17.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-18.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-19.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-20.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-21.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-22.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-23.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-24.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-25.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-26.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-27.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-28.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-29.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-30.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-31.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-32.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-33.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-34.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-35.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-36.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-37.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-38.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-39.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-40.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-41.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-42.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-43.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-44.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-45.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-46.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-47.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-48.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-49.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-50.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-51.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-52.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-53.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-54.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-55.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-56.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-57.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-58.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-59.png')]

# %% [markdown]
# ## Render directly from MuseScore

# %%
def render_musescore(
  mscore_path:Union[PathLike,None],
  fmt:str='png',
  out:PathLike=None,
  dpi:Optional[int]=90,
  mscore_exec:str='musescore3'
) -> Union[list[PathLike],list[np.array],None]:
  """
  modified function from partitura.io.musescore.render_musescore
  Render a score-like object using musescore.

  Parameters
  ----------
  mscore_path : PathLike or None
    MuseScore file path to be rendered
  fmt : {'png', 'pdf'}
    Output image format
  out : Path or str or None
    'png': OPTIONAL
    'pdf': REQUIRED
  dpi : int, optional
    Image resolution. 
    This option is ignored when `fmt` is 'pdf'. 
    Defaults to 90.

  Returns
  -------
  out : 
    1. list[PathLike]: list of paths to output images if out is provided
    2. list[np.array]: list of images if out is not provided
    3. None: if no image was generated
  """
  
  assert fmt in {'png', 'pdf'}, "Unsupported output format"
  
  if fmt == 'pdf':
    assert out is not None, "Output path is required for 'pdf' format"

  with TemporaryDirectory() as tmpdir:
    img_fh = Path(tmpdir) / f"score.{fmt}"
    
    cmd = [
      mscore_exec,
      # "-T",
      # "10",
      "-r",
      "{}".format(int(dpi)),
      "-o",
      os.fspath(img_fh),
      os.fspath(mscore_path),
      "-f",
    ]
    try:
      ps = subprocess.run(
        cmd, 
        stdout=subprocess.PIPE, stderr=subprocess.PIPE,
        env=dict(QT_QPA_PLATFORM='offscreen', **os.environ) # run MuseScore3 in headless mode
      )
      
      if ps.returncode != 0:
        raise Exception(
          "Command {} failed with code {}; stdout: {}; stderr: {}"
          .format(
            cmd,
            ps.returncode,
            ps.stdout.decode("UTF-8"),
            ps.stderr.decode("UTF-8"),
          )
        )
    
    except Exception as e:
      raise Exception(
        'Executing "{}" returned  {}.'
        .format(" ".join(cmd), e),
      )
    
    if fmt == "png":
      # gether all generated image files
      img_files = list(sorted(Path(tmpdir).glob(f"*.{fmt}")))
      
      # if no image was generated
      if len(img_files) < 1:
        return None
      
      # return images if out is not provided
      if out is None:
        out_images = [ cv2.imread(i_fp) for i_fp in img_files ]
        return out_images

      # return paths of images if out is provided
      else:
        out_files = [ out/i_fp.name for i_fp in img_files ]
        for i_fp, o_fp in zip(img_files, out_files):
          # make background white
          o_i = cv2.imread(i_fp, cv2.IMREAD_UNCHANGED)
          transparent_mask = o_i[:,:,3] == 0
          o_i[transparent_mask] = [255, 255, 255, 255]
          o_i = cv2.cvtColor(o_i, cv2.COLOR_BGRA2BGR)
          cv2.imwrite(o_fp, o_i)
        return out_files
    
    elif fmt == "pdf":
      if img_fh.is_file():
        shutil.copy(img_fh, out/img_fh.name)
      else:
        return None
    
    # if no image was generated
    return None

# %%
mscore_out_dir = mscore_dir / 'images' / 'original'
mscore_out_dir.mkdir(parents=True, exist_ok=True)

render_musescore(
  mscore_path,
  fmt='png',
  out=mscore_out_dir,
  dpi=300,
)
# Out:
# [PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-01.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-02.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-03.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-04.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-05.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-06.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-07.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-08.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-09.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-10.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-11.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-12.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-13.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-14.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-15.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-16.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-17.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-18.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-19.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-20.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-21.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-22.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-23.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-24.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-25.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-26.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-27.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-28.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-29.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-30.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-31.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-32.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-33.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-34.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/original/score-35.png')]

# %% [markdown]
# ## Render with Lilypond

# %%
def render_lilypond(
  musicxml_path:PathLike,
  fmt:str="png",
  out:Optional[PathLike]=None,
) -> Union[list[PathLike],list[np.array],None]:
  """
  Render a score-like object using Lilypond

  Parameters
  ----------
  musicxml_path : PathLike
  fmt : {'png', 'pdf'}
    Output image format

  Returns
  -------
  out : 
    1. list[PathLike]: list of paths to output images if out is provided
    2. list[np.array]: list of images if out is not provided
    3. None: if no image was generated
  """
  assert fmt in {'png', 'pdf'}, "Unsupported output format"
  
  if fmt == 'pdf':
    assert out is not None, "Output path is required for 'pdf' format"

  with TemporaryDirectory() as tmpdir:
    pt_xml = Path(tmpdir) / "score.xml"
    pt.save_musicxml(pt.load_musicxml(musicxml_path), pt_xml)
    
    # convert musicxml to lilypond format (use stdout pipe)
    cmd1 = ["musicxml2ly", "-o-", str(pt_xml)]
    try:
      ps1 = subprocess.run(
        cmd1, stdout=subprocess.PIPE, check=False
      )
      if ps1.returncode != 0:
        raise Exception(
          "Command {} failed with code {}".format(cmd1, ps1.returncode)
        )
    
    except Exception as e:
      raise Exception(
        'Executing "{}" returned  {}.'
        .format(" ".join(cmd1), e),
      )

    # convert lilypond format (read from pipe of ps1) to image, and save to
    # temporary filename
    cmd2 = [
      "lilypond",
      "--{}".format(fmt),
      "-dprint-pages",
      "-o{}".format(tmpdir + '/score'),
      "-",
    ]
    try:
      ps2 = subprocess.run(cmd2, input=ps1.stdout, check=False)
      
      if ps2.returncode != 0:
        raise Exception(
          "Command {} failed with following error {}".format(cmd2, ps2.stderr)
        )
    
    except Exception as e:
      print(e)
      return
    
    if fmt == "png":
      # gether all generated image files
      img_files = list(sorted(Path(tmpdir).glob(f"*.{fmt}")))
      
      # if no image was generated
      if len(img_files) < 1:
        return None
      
      # return images if out is not provided
      if out is None:
        out_images = [ cv2.imread(i_fp) for i_fp in img_files ]
        return out_images

      # return paths of images if out is provided
      else:
        out_files = [ out/i_fp.name for i_fp in img_files ]
        for i_fp, o_fp in zip(img_files, out_files):
          shutil.copy(i_fp, o_fp)
        return out_files
    
    elif fmt == "pdf":
      pdf_file, *_ = list(Path(tmpdir).glob(f"*.{fmt}"))
      
      if pdf_file.is_file():
        shutil.copy(pdf_file, out/pdf_file.name)
      else:
        return None
    
    # if no image was generated
    return None

# %%
data = mscore_data[0]
mscore_dir = score_dir / data['path']
musicxml_path = mscore_dir / f"sq{data['mscore_id']}.musicxml"

lily_out_dir = mscore_dir / 'images' / 'lilypond'
lily_out_dir.mkdir(parents=True, exist_ok=True)

render_lilypond(
  musicxml_path,
  fmt='png',
  out=lily_out_dir,
)
# Out:
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1014: UserWarning: Dashes end without dashes start
#   warnings.warn("Dashes end without dashes start")
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:927: UserWarning: Did not find a wedge start element for wedge stop!
#   warnings.warn("Did not find a wedge start element for wedge stop!")
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "sul G" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "tranquillo" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "con sordino" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "Allegretto [Dubbelt da fort]" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "allarg." (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "3" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "rd" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing " corde" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-y': '3.83', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-y': '0.95', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-y': '15.55', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-y': '29.96', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-y': '21.24', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-y': '21.09', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-y': '32.97', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1005: UserWarning: ignoring direction type: metronome {'parentheses': 'no', 'default-x': '-34.94', 'relative-y': '20.00'}
#   warnings.warn("ignoring direction type: {} {}".format(dt.tag, dt.attrib))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/io/importmusicxml.py:429: UserWarning: Found repeat without start
# Starting point 0 is assumed
#   warnings.warn(
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "più svart " (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "pizz." (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/dongmin/.local/share/virtualenvs/open-score-string-quartets-wd2Cnojv/lib/python3.10/site-packages/partitura/directions.py:514: UserWarning: error parsing "arco" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# musicxml2ly: Reading MusicXML from /tmp/tmp8klo6ouu/score.xml ...
# musicxml2ly: Converting to LilyPond expressions...
# musicxml2ly: warning: Negative skip -1 (from position 75 to 74)
# musicxml2ly: warning: Negative skip -1 (from position 236 to 235)
# musicxml2ly: Converting to LilyPond expressions...
# musicxml2ly: Converting to LilyPond expressions...
# musicxml2ly: warning: Negative skip -1 (from position 75 to 74)
# musicxml2ly: warning: Negative skip -1 (from position 291 to 290)
# musicxml2ly: warning: Negative skip -1/2 (from position 581/2 to 290)
# musicxml2ly: warning: Negative skip -1/2 (from position 581/2 to 290)
# musicxml2ly: warning: Negative skip -1/2 (from position 581/2 to 290)
# musicxml2ly: Converting to LilyPond expressions...
# musicxml2ly: Converting to LilyPond expressions...
# musicxml2ly: warning: Cannot have two simultaneous slurs
#   In: <slur number=1 type=start>
#
#   In: <notations >
#
#   In: <note >
#
#   In: <measure number=195>
#
#   In: <part id=P3>
#
#   In: <score-partwise >
#
# musicxml2ly: warning: Cannot have two simultaneous (closing) slurs
#   In: <slur number=1 type=stop>
#
#   In: <notations >
#
#   In: <note >
#
#   In: <measure number=195>
#
#   In: <part id=P3>
#
#   In: <score-partwise >
#
# musicxml2ly: warning: Cannot have a slur inside another slur
#   In: <slur number=2 type=start>
#
#   In: <notations >
#
#   In: <note >
#
#   In: <measure number=260>
#
#   In: <part id=P3>
#
#   In: <score-partwise >
#
# musicxml2ly: warning: Encountered closing slur, but no slur is open
#   In: <slur number=1 type=stop>
#
#   In: <notations >
#
#   In: <note >
#
#   In: <measure number=261>
#
#   In: <part id=P3>
#
#   In: <score-partwise >
#
# musicxml2ly: Converting to LilyPond expressions...
# musicxml2ly: Converting to LilyPond expressions...
# musicxml2ly: warning: Negative skip -1 (from position 108 to 107)
# musicxml2ly: warning: Negative skip -1/2 (from position 215/2 to 107)
# musicxml2ly: warning: Negative skip -1/2 (from position 215/2 to 107)
# musicxml2ly: warning: Negative skip -1/2 (from position 215/2 to 107)
# musicxml2ly: warning: Negative skip -1 (from position 108 to 107)
# musicxml2ly: warning: Negative skip -1/2 (from position 215/2 to 107)
# musicxml2ly: warning: Negative skip -1/2 (from position 215/2 to 107)
# musicxml2ly: warning: Negative skip -1/2 (from position 215/2 to 107)
# musicxml2ly: warning: Cannot have two simultaneous slurs
#   In: <slur number=1 type=start>
#
#   In: <notations >
#
#   In: <note >
#
#   In: <measure number=195>
#
#   In: <part id=P4>
#
#   In: <score-partwise >
#
# musicxml2ly: warning: Cannot have two simultaneous (closing) slurs
#   In: <slur number=1 type=stop>
#
#   In: <notations >
#
#   In: <note >
#
#   In: <measure number=195>
#
#   In: <part id=P4>
#
#   In: <score-partwise >
#
# musicxml2ly: warning: Negative skip -1 (from position 207 to 206)
# musicxml2ly: warning: Negative skip -1 (from position 291 to 290)
# musicxml2ly: Converting to LilyPond expressions...
# musicxml2ly: Output to `Standard output'
# musicxml2ly: warning: Encountered unprocessed marker <musicxml2ly_conversion.RepeatMarker object at 0x7eda5e56ded0>
#
# musicxml2ly: warning: Encountered unprocessed marker <musicxml2ly_conversion.RepeatMarker object at 0x7eda5e69a590>
#
# musicxml2ly: warning: Encountered unprocessed marker <musicxml2ly_conversion.RepeatMarker object at 0x7eda5e435d50>
#
# musicxml2ly: warning: Encountered unprocessed marker <musicxml2ly_conversion.RepeatMarker object at 0x7eda5e4d4100>
#
# musicxml2ly: warning: Encountered unprocessed marker <musicxml2ly_conversion.RepeatMarker object at 0x7eda5e3984f0>
#
# musicxml2ly: warning: Encountered unprocessed marker <musicxml2ly_conversion.RepeatMarker object at 0x7eda5e5215a0>
#
# musicxml2ly: warning: Encountered unprocessed marker <musicxml2ly_conversion.RepeatMarker object at 0x7eda5e2117b0>
#
# musicxml2ly: warning: Encountered unprocessed marker <musicxml2ly_conversion.RepeatMarker object at 0x7eda5e3a8f70>
#
# Changing working directory to: `/tmp/tmp8klo6ouu'
# Processing `-'
# Parsing...
# Interpreting music...[8][16][24][32][40][48][56][64][72][80][88][96][104][112][120][128][136][144][152][160][168][176][184][192][200][208][216][224][232][240][248][256][264][272][280][288][296][304][312][320][328][336][344][352][360][368][376][384][392][400][408][416][424][432][440][448][456][464][472][480][488][496][504][512][520][528][536][544][552][560][568][576][584][592][600][608][616][624][632][640][648][656][664][672][680][688][696][704][712][720][728][736][744][752][760][768][776][784][792][800][808][816]
# -:907:11: warning: unterminated decrescendo
#     r4 r2
#           -\> r4 \break s1*5 \break s1*6 \break \pageBreak s1*5 \break
# -:1801:35: warning: unterminated crescendo
#     \break \pageBreak r2. -\mf r4
#                                   -\< s1*3 \break s1*5 \break s1*5
# [824]
# Preprocessing graphical objects...
# Finding the ideal number of pages...
# Fitting music on 75 or 76 pages...
# Drawing systems...
# Converting to PNG...
# Success: compilation successfully completed
# [PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page1.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page10.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page11.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page12.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page13.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page14.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page15.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page16.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page17.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page18.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page19.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page2.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page20.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page21.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page22.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page23.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page24.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page25.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page26.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page27.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page28.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page29.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page3.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page30.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page31.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page32.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page33.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page34.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page35.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page36.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page37.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page38.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page39.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page4.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page40.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page41.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page42.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page43.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page44.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page45.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page46.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page47.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page48.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page49.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page5.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page50.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page51.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page52.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page53.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page54.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page55.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page56.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page57.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page58.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page59.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page6.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page60.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page61.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page62.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page63.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page64.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page65.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page66.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page67.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page68.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page69.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page7.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page70.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page71.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page72.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page73.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page74.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page75.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page76.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page8.png'),
#  PosixPath('/home/dongmin/userdata/open-score-string-quartets/scores/Andrée,_Elfrida/String_Quartet_in_A_major/images/lilypond/score-page9.png')]
